# %%
# %pylab inline
import numpy as np
import sklearn.linear_model as linear
import sklearn.model_selection as selection
import sklearn.metrics as metrics
import sklearn.datasets as datasets
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.random.uniform(-10, 10, size=100)
y = 2 * x ** 3 + 5 * x ** 2 - 4 * x + 2 + np.random.normal(1000, 150, size=100)

# %%
x = x.reshape(-1, 1)
y = y.reshape(-1, 1)
z = np.concatenate((x, y), axis=1)

# %%
z.shape
# Out:
# (100, 2)

# %%
with open('polynomial_data.npy', 'wb') as fp:
    np.save(fp, z)

# %%
X, y = datasets.make_moons(n_samples=1000, noise=0.15, shuffle=True)
colors = np.array(['red' if x == 0 else 'blue' for x in y])

# %%
plt.scatter(X[:,0], X[:,1],c=colors)

# %%
with open('X.npy', 'wb') as fp:
    np.save(fp, X)
    
with open('y.npy', 'wb') as fp:
    np.save(fp, y)
